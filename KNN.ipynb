# %%
import pandas as pd
import numpy as np

# %%
places_data=pd.read_csv("Places_Pune_OneHotEncoded.csv")
restaurants_data=pd.read_csv("Restaurant_Data_Pune.csv")
hotels_data=pd.read_csv("cleaned_hotels.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 places_data=pd.read_csv("Places_Pune_OneHotEncoded.csv")
# ----> 2 restaurants_data=pd.read_csv("Restaurant_Data_Pune.csv")
#       3 hotels_data=pd.read_csv("cleaned_hotels.csv")
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\miniconda3\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Restaurant_Data_Pune.csv'

# %%
places_data = places_data.reset_index(drop=True)

# %%
print("places_data shape:", places_data.shape)
print("restaurants_data shape:", restaurants_data.shape)
print("hotels_data shape:", hotels_data.shape)

# %%
print("Indices Restaurants shape:", indices_restaurants.shape)
print("Indices Hotels shape:", indices_hotels.shape)

# %%
# Reset index before merging to avoid length mismatch issue
places_data = places_data.reset_index(drop=True)
restaurants_data = restaurants_data.reset_index(drop=True)
hotels_data = hotels_data.reset_index(drop=True)

# Add 'Nearest_Place_Index' column to restaurants_data and hotels_data
restaurants_data['Nearest_Place_Index'] = indices_restaurants.flatten()
hotels_data['Nearest_Place_Index'] = indices_hotels.flatten()

# Merge the 'places_data' DataFrame with 'restaurants_data' and 'hotels_data' based on the 'Nearest_Place_Index'
restaurants_data = pd.merge(restaurants_data, places_data, left_on='Nearest_Place_Index', right_index=True, suffixes=('_restaurant', '_place'))
hotels_data = pd.merge(hotels_data, places_data, left_on='Nearest_Place_Index', right_index=True, suffixes=('_hotel', '_place'))

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data

# Drop unnecessary columns for the matching process
places_features = places_data[['Longitude', 'Latitude']]
restaurants_features = restaurants_data[['Longitude', 'Latitude']]
hotels_features = hotels_data[['Longitude', 'Latitude']]

# Use Nearest Neighbors to find the nearest place for each restaurant/hotel
knn = NearestNeighbors(n_neighbors=4, metric='haversine')
knn.fit(places_features)

# Find the nearest places and distances for each restaurant
distances_restaurants, indices_restaurants = knn.kneighbors(restaurants_features)

# Find the nearest places and distances for each hotel
distances_hotels, indices_hotels = knn.kneighbors(hotels_features)

# Create columns for each nearest place and distance in restaurants_data
for i in range(indices_restaurants.shape[1]):
    restaurants_data[f'Nearest_Place_Index_{i}'] = indices_restaurants[:, i]
    restaurants_data[f'Distance_to_Place_{i}'] = distances_restaurants[:, i]

# Create columns for each nearest place and distance in hotels_data
for i in range(indices_hotels.shape[1]):
    hotels_data[f'Nearest_Place_Index_{i}'] = indices_hotels[:, i]
    hotels_data[f'Distance_to_Place_{i}'] = distances_hotels[:, i]

# Merge the 'places_data' DataFrame with 'restaurants_data' and 'hotels_data' based on the indices
for i in range(indices_restaurants.shape[1]):
    restaurants_data = pd.merge(restaurants_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=('_restaurant', f'_place_{i}'))

for i in range(indices_hotels.shape[1]):
    hotels_data = pd.merge(hotels_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=('_hotel', f'_place_{i}'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       2 from sklearn.neighbors import NearestNeighbors
#       4 # Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data
#       5
#       6 # Drop unnecessary columns for the matching process
# ----> 7 places_features = places_data[['Longitude', 'Latitude']]
#       8 restaurants_features = restaurants_data[['Longitude', 'Latitude']]
#       9 hotels_features = hotels_data[['Longitude', 'Latitude']]
#
# NameError: name 'places_data' is not defined

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data

# Drop unnecessary columns for the matching process
places_features = places_data[['Longitude', 'Latitude']]
restaurants_features = restaurants_data[['Longitude', 'Latitude']]
hotels_features = hotels_data[['Longitude', 'Latitude']]

# Use Nearest Neighbors to find the nearest place for each restaurant/hotel
knn = NearestNeighbors(n_neighbors=4, metric='haversine')
knn.fit(places_features)

# Find the nearest places and distances for each restaurant
distances_restaurants, indices_restaurants = knn.kneighbors(restaurants_features)

# Find the nearest places and distances for each hotel
distances_hotels, indices_hotels = knn.kneighbors(hotels_features)

# Create columns for each nearest place and distance in restaurants_data
for i in range(indices_restaurants.shape[1]):
    restaurants_data[f'Nearest_Place_Index_{i}'] = indices_restaurants[:, i]
    restaurants_data[f'Distance_to_Place_{i}'] = distances_restaurants[:, i]

# Create columns for each nearest place and distance in hotels_data
for i in range(indices_hotels.shape[1]):
    hotels_data[f'Nearest_Place_Index_{i}'] = indices_hotels[:, i]
    hotels_data[f'Distance_to_Place_{i}'] = distances_hotels[:, i]

# Merge the 'places_data' DataFrame with 'restaurants_data' based on the indices
for i in range(indices_restaurants.shape[1]):
    suffix = f'_place_{i}'
    restaurants_data = pd.merge(restaurants_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=(f'_restaurant{i}', suffix))

# Merge the 'places_data' DataFrame with 'hotels_data' based on the indices
for i in range(indices_hotels.shape[1]):
    suffix = f'_place_{i}'
    hotels_data = pd.merge(hotels_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=(f'_hotel{i}', suffix))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       2 from sklearn.neighbors import NearestNeighbors
#       4 # Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data
#       5
#       6 # Drop unnecessary columns for the matching process
# ----> 7 places_features = places_data[['Longitude', 'Latitude']]
#       8 restaurants_features = restaurants_data[['Longitude', 'Latitude']]
#       9 hotels_features = hotels_data[['Longitude', 'Latitude']]
#
# NameError: name 'places_data' is not defined

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data

# Drop unnecessary columns for the matching process
places_features = places_data[['Longitude', 'Latitude']]
restaurants_features = restaurants_data[['Longitude', 'Latitude']]
hotels_features = hotels_data[['Longitude', 'Latitude']]

# Use Nearest Neighbors to find the nearest place for each restaurant/hotel
knn = NearestNeighbors(n_neighbors=1, metric='haversine')
knn.fit(places_features)

# Find the nearest places and distances for each restaurant
distances_restaurants, indices_restaurants = knn.kneighbors(restaurants_features)

# Find the nearest places and distances for each hotel
distances_hotels, indices_hotels = knn.kneighbors(hotels_features)

# Create columns for each nearest place and distance in restaurants_data
for i in range(indices_restaurants.shape[1]):
    restaurants_data[f'Nearest_Place_Index_{i}'] = indices_restaurants[:, i]
    restaurants_data[f'Distance_to_Place_{i}'] = distances_restaurants[:, i]

# Create columns for each nearest place and distance in hotels_data
for i in range(indices_hotels.shape[1]):
    hotels_data[f'Nearest_Place_Index_{i}'] = indices_hotels[:, i]
    hotels_data[f'Distance_to_Place_{i}'] = distances_hotels[:, i]

# Merge the 'places_data' DataFrame with 'restaurants_data' based on the indices
for i in range(indices_restaurants.shape[1]):
    suffix = f'_place_{i}'
    restaurants_data = pd.merge(restaurants_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=('', suffix))

# Merge the 'places_data' DataFrame with 'hotels_data' based on the indices
for i in range(indices_hotels.shape[1]):
    suffix = f'_place_{i}'
    hotels_data = pd.merge(hotels_data, places_data, left_on=f'Nearest_Place_Index_{i}', right_index=True, suffixes=('', suffix))

# Merge restaurants_data and hotels_data into a single DataFrame
merged_data = pd.merge(restaurants_data, hotels_data, left_on='Nearest_Place_Index_0', right_on='Nearest_Place_Index_0')

# Save the resulting DataFrame as a CSV file
merged_data.to_csv('combined_data1.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       2 from sklearn.neighbors import NearestNeighbors
#       4 # Assuming you have three DataFrames: places_data, restaurants_data, and hotels_data
#       5
#       6 # Drop unnecessary columns for the matching process
# ----> 7 places_features = places_data[['Longitude', 'Latitude']]
#       8 restaurants_features = restaurants_data[['Longitude', 'Latitude']]
#       9 hotels_features = hotels_data[['Longitude', 'Latitude']]
#
# NameError: name 'places_data' is not defined

# %%
import pandas as pd
from sklearn.metrics.pairwise import haversine_distances, cosine_similarity
from math import radians

# Load the combined dataset
combined_data = pd.read_csv('Final_Prepared_data2.0.csv')

# Example user input
user_budget_level = 4  # Example user budget level criterion
user_hotel_rating = 4  # Example user rating criterion
user_hotel_star_rating = 4 # Example user hotel star rating criterion
user_restaurant_rating = 5  # Example user restaurant rating criterion

# Filter based on user criteria, including the new budget level
filtered_data = combined_data[
    (combined_data['budget_level'] == user_budget_level) &
    (combined_data['mmt_review_score_Hotel'] >= user_hotel_rating) &
    (combined_data['hotel_star_rating_Hotel'] >= user_hotel_star_rating) &
    (combined_data['Ratings_out_of_5_Restaurant'] >= user_restaurant_rating)
]

# Select the first restaurant based on budget level
selected_restaurant = filtered_data.iloc[0]

# Function to calculate Haversine distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dist = haversine_distances([[lat1, lon1], [lat2, lon2]]) * 6371000  # Earth radius in meters
    return dist[1, 0]

# Apply the distance calculation to hotels
filtered_data['distance_to_restaurant'] = filtered_data.apply(
    lambda row: calculate_distance(
        selected_restaurant['Latitude_x__Restaurant'],
        selected_restaurant['Longitude_x__Restaurant'],
        row['Latitude_Hotel'],
        row['Longitude_Hotel']
    ),
    axis=1
)

# Rank hotels based on distance and additional criteria
ranked_hotels = filtered_data[filtered_data['Hotel_name'].notnull()].sort_values(
    by=['distance_to_restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']
)

# Select the nearest hotel
nearest_hotel = ranked_hotels.iloc[0]

# Apply the distance calculation to places
filtered_data['distance_to_restaurant'] = filtered_data.apply(
    lambda row: calculate_distance(
        selected_restaurant['Latitude_x__Restaurant'],
        selected_restaurant['Longitude_x__Restaurant'],
        row['Latitude_place_0_x'],
        row['Longitude_place_0_x']
    ),
    axis=1
)

# Rank places based on distance
ranked_places = filtered_data[filtered_data['Name_Place'].notnull()].sort_values(by='distance_to_restaurant')

# Select the nearest place
nearest_place = ranked_places.iloc[0]

# Collaborative Filtering - Content Similarity
hotel_profiles = filtered_data[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]
place_profiles = filtered_data[['Rating_Place', 'Ratings_out_of_5_Restaurant', 'budget_level']]

selected_hotel_profile = selected_restaurant[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]

hotel_similarity = cosine_similarity([selected_hotel_profile], hotel_profiles)
place_similarity = cosine_similarity([selected_hotel_profile], place_profiles)

# Get top 4 hotels and places based on similarity
top_hotels = ranked_hotels.iloc[hotel_similarity.argsort()[0][::-1][:4]]
top_places = ranked_places.iloc[place_similarity.argsort()[0][::-1][:4]]

# Display the recommendations
print("Recommendations:")
print("-----------------")
print(f"Recommended Restaurant: {selected_restaurant['Restaurant_Name']}")
print(f"Nearest Hotel: {nearest_hotel['Hotel_name']}")
print(f"Nearest Place: {nearest_place['Name_Place']}")
print("\nAdditional Information:")
print("-----------------------")
print(f"Distance to Restaurant: {nearest_hotel['distance_to_restaurant']:.2f} meters")
print(f"Hotel Rating: {nearest_hotel['mmt_review_score_Hotel']}")
print(f"Hotel Star Rating: {nearest_hotel['hotel_star_rating_Hotel']}")
print(f"Restaurant Rating: {selected_restaurant['Ratings_out_of_5_Restaurant']}")

print("\nCollaborative Filtering - Top 4 Hotels:")
print(top_hotels[['Hotel_name', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'distance_to_restaurant']])
print("\nCollaborative Filtering - Top 4 Places:")
print(top_places[['Name_Place', 'Ratings_out_of_5_Restaurant', 'distance_to_restaurant']])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 23
#      15 filtered_data = combined_data[
#      16     (combined_data['budget_level'] == user_budget_level) &
#      17     (combined_data['mmt_review_score_Hotel'] >= user_hotel_rating) &
#      18     (combined_data['hotel_star_rating_Hotel'] >= user_hotel_star_rating) &
#      19     (combined_data['Ratings_out_of_5_Restaurant'] >= user_restaurant_rating)
#      20 ]
#      22 # Select the first restaurant based on budget level
# ---> 23 selected_restaurant = filtered_data.iloc[0]
#      25 # Function to calculate Haversine distance between two coordinates
#      26 def calculate_distance(lat1, lon1, lat2, lon2):
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
import pandas as pd
from sklearn.metrics.pairwise import haversine_distances, cosine_similarity
from math import radians

# Load the combined dataset
combined_data = pd.read_csv('dataset_without_duplicates.csv')

# Remove duplicate entries
combined_data.drop_duplicates(inplace=True)

# Example user input
user_budget_level = 1# Example user budget level criterion
user_hotel_rating = 1  # Example user rating criterion
user_hotel_star_rating = 1 # Example user hotel star rating criterion
user_restaurant_rating = 1  # Example user restaurant rating criterion

# Filter based on user criteria, including the new budget level
filtered_data = combined_data[
    (combined_data['budget_level'] == user_budget_level) &
    (combined_data['mmt_review_score_Hotel'] >= user_hotel_rating) &
    (combined_data['hotel_star_rating_Hotel'] == user_hotel_star_rating) &
    (combined_data['Ratings_out_of_5_Restaurant'] >= user_restaurant_rating)
]

# Check if the filtered dataset is empty
if filtered_data.empty:
    print("No suitable recommendations found based on the provided criteria.")
else:
    # Select the first restaurant based on budget level
    selected_restaurant = filtered_data.iloc[0]

    # Function to calculate Haversine distance between two coordinates
    def calculate_distance(lat1, lon1, lat2, lon2):
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
        dist = haversine_distances([[lat1, lon1], [lat2, lon2]]) * 6371000  # Earth radius in meters
        return dist[1, 0]

    # Apply the distance calculation to hotels
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_Hotel'],
            row['Longitude_Hotel']
        ),
        axis=1
    )

    # Rank hotels based on distance and additional criteria
    ranked_hotels = filtered_data[filtered_data['Hotel_name'].notnull()].sort_values(
        by=['distance_to_restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']
    )

    # Select the nearest hotel if there are any
    if not ranked_hotels.empty:
        nearest_hotel = ranked_hotels.iloc[0]
    else:
        nearest_hotel = None

    # Apply the distance calculation to places
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_place_0_x'],
            row['Longitude_place_0_x']
        ),
        axis=1
    )

    # Rank places based on distance
    ranked_places = filtered_data[filtered_data['Name_Place'].notnull()].sort_values(by='distance_to_restaurant')

    # Select the nearest place if there are any
    if not ranked_places.empty:
        nearest_place = ranked_places.iloc[0]
    else:
        nearest_place = None

    # Collaborative Filtering - Content Similarity
    hotel_profiles = filtered_data[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]
    place_profiles = filtered_data[['Rating_Place', 'Ratings_out_of_5_Restaurant', 'budget_level']]

    selected_hotel_profile = selected_restaurant[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]

    hotel_similarity = cosine_similarity([selected_hotel_profile], hotel_profiles)
    place_similarity = cosine_similarity([selected_hotel_profile], place_profiles)

    # Get top 4 hotels and places based on similarity
    top_hotels = ranked_hotels.iloc[hotel_similarity.argsort()[0][::-1][:4]]
    top_places = ranked_places.iloc[place_similarity.argsort()[0][::-1][:4]]

    # Display the recommendations
    print("Recommendations:")
    print("-----------------")
    print(f"Recommended Restaurant: {selected_restaurant['Restaurant_Name']}")

    if nearest_hotel is not None:
        print(f"Nearest Hotel: {nearest_hotel['Hotel_name']}")
    else:
        print("No hotels found meeting the criteria.")

    if nearest_place is not None:
        print(f"Nearest Place: {nearest_place['Name_Place']}")
    else:
        print("No places found meeting the criteria.")

    print("\nAdditional Information:")
    print("-----------------------")

    if nearest_hotel is not None:
        print(f"Distance to Nearest Hotel: {nearest_hotel['distance_to_restaurant']:.2f} meters")
        print(f"Hotel Rating: {nearest_hotel['mmt_review_score_Hotel']}")
        print(f"Hotel Star Rating: {nearest_hotel['hotel_star_rating_Hotel']}")
    else:
        print("No hotels found meeting the criteria.")

    print(f"Restaurant Rating: {selected_restaurant['Ratings_out_of_5_Restaurant']}")

    print("\nCollaborative Filtering - Top 4 Hotels:")
    print(top_hotels[['Hotel_name', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'distance_to_restaurant']])
    print("\nCollaborative Filtering - Top 4 Places:")
    print(top_places[['Name_Place', 'Ratings_out_of_5_Restaurant', 'distance_to_restaurant']])
# Out:
# C:\Users\Athar\AppData\Local\Temp\ipykernel_9240\3534293151.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# Recommendations:
# -----------------
# Recommended Restaurant: Hotel Jagdamba
# Nearest Hotel: Hotel Yashraj Inn
# Nearest Place: Phoenix Marketcity Pune
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 1399882.26 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 4.4
#
# Collaborative Filtering - Top 4 Hotels:
#              Hotel_name  mmt_review_score_Hotel  hotel_star_rating_Hotel  \
# 835   Hotel Yashraj Inn                     3.5                        1
# 2795  Hotel Yashraj Inn                     3.5                        1
# 2945  Hotel Yashraj Inn                     3.5                        1
# 2925  Hotel Yashraj Inn                     3.5                        1
#
#       distance_to_restaurant
# 835             1.399882e+06
# 2795            1.399882e+06
# 2945            1.399882e+06
# 2925            1.399882e+06
#
# Collaborative Filtering - Top 4 Places:
#                                   Name_Place  Ratings_out_of_5_Restaurant  \
# 6280                           Chattushringi                          4.3
# 7035  Shri Ahobila Mutt's Shri Balaji Mandir                          4.0
# 3432               Raja Dinkar Kelkar Museum                          4.6
# 4300    Phoenix Mall of the Millennium Wakad                          3.6
#
#       distance_to_restaurant
# 6280            1.413462e+06
# 7035            1.413526e+06
# 3432            1.419402e+06
# 4300            1.413317e+06
# C:\Users\Athar\AppData\Local\Temp\ipykernel_9240\3534293151.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(

# %%
import pandas as pd

# Assuming your DataFrame is named 'df' and the budget column is named 'budget'
# You can replace these names with your actual DataFrame and column names

# Define the number of levels
num_levels = 5

# Create a new column 'budget_level' and assign levels based on the range
combined_data['budget_level'] = pd.qcut(combined_data['budget'], q=num_levels, labels=[f'{i+1}' for i in range(num_levels)])

# Display the DataFrame with the new column
print(combined_data)
# Out:
#       Unnamed: 0            Restaurant_Name Locality_Restaurant  \
# 0              0  AB's - Absolute Barbecues           Hinjawadi
# 1              1  AB's - Absolute Barbecues           Hinjawadi
# 2              2  AB's - Absolute Barbecues           Hinjawadi
# 3              3  AB's - Absolute Barbecues           Hinjawadi
# 4              4  AB's - Absolute Barbecues           Hinjawadi
# ...          ...                        ...                 ...
# 7738        7738               Sambar House         Mulshi Road
# 7739        7739             The Hungry Hog              Lavale
# 7740        7740             The Hungry Hog              Lavale
# 7741        7741     Rudra Restaurant & Bar         Mulshi Road
# 7742        7742     Rudra Restaurant & Bar         Mulshi Road
#
#       Ratings_out_of_5_Restaurant  Price_Restaurant  Price Level__Restaurant  \
# 0                             4.9               700                        2
# 1                             4.9               700                        2
# 2                             4.9               700                        2
# 3                             4.9               700                        2
# 4                             4.9               700                        2
# ...                           ...               ...                      ...
# 7738                          0.0                75                        1
# 7739                          0.0               125                        1
# 7740                          0.0               125                        1
# 7741                          3.1               350                        1
# 7742                          3.1               350                        1
#
#       Latitude_x__Restaurant  Longitude_x__Restaurant  Nearest_Place_Index_0  \
# 0                  18.592753                73.738215                     44
# 1                  18.592753                73.738215                     44
# 2                  18.592753                73.738215                     44
# 3                  18.592753                73.738215                     44
# 4                  18.592753                73.738215                     44
# ...                      ...                      ...                    ...
# 7738               18.611846                73.717142                     38
# 7739               18.523023                73.722401                     38
# 7740               18.523023                73.722401                     38
# 7741               18.611846                73.717142                     38
# 7742               18.611846                73.717142                     38
#
#       Distance_to_Place_0_from__Restaurant  ...  \
# 0                                 0.002686  ...
# 1                                 0.002686  ...
# 2                                 0.002686  ...
# 3                                 0.002686  ...
# 4                                 0.002686  ...
# ...                                    ...  ...
# 7738                              0.005226  ...
# 7739                              0.006212  ...
# 7740                              0.006212  ...
# 7741                              0.005226  ...
# 7742                              0.005226  ...
#
#                                    Hotel_name                   area_Hotel  \
# 0                     Executive Tamanna Hotel        Hinjewadi,Aundh,Wakad
# 1      Ashiyana Hospitality Service Apartment                    Hinjewadi
# 2                       Siesta Hinjewadi Lxia   Hinjewadi,Wakad Naka,Wakad
# 3     Riverdale Hospitality Service Apartment                    Hinjewadi
# 4                          Hotel Elite Galaxy  Rajiv Gandhi Infotech Park,
# ...                                       ...                          ...
# 7738   Innovative Service Apartment Hinjewadi                    Hinjewadi
# 7739                            Gourish Hotel           Shivajinagar, pune
# 7740   Innovative Service Apartment Hinjewadi                    Hinjewadi
# 7741                            Gourish Hotel           Shivajinagar, pune
# 7742   Innovative Service Apartment Hinjewadi                    Hinjewadi
#
#       hotel_star_rating_Hotel  mmt_review_score_Hotel Price_Hotel  \
# 0                           2                     3.7        1900
# 1                           1                     3.4        2447
# 2                           3                     4.5        1893
# 3                           1                     2.8        2140
# 4                           2                     4.0        1413
# ...                       ...                     ...         ...
# 7738                        1                     5.0        1200
# 7739                        1                     4.1        1177
# 7740                        1                     5.0        1200
# 7741                        1                     4.1        1177
# 7742                        1                     5.0        1200
#
#       Longitude_Hotel  Latitude_Hotel  Distance_to_Place_form_Hotel  budget  \
# 0           73.734974       18.585750                      0.000683    2600
# 1           73.740133       18.578061                      0.004711    3147
# 2           73.745629       18.591736                      0.010089    2593
# 3           73.736188       18.580314                      0.001087    2840
# 4           73.732535       18.599672                      0.003142    2113
# ...               ...             ...                           ...     ...
# 7738        73.718290       18.592497                      0.003007    1275
# 7739        73.681119       17.951461                      0.084696    1302
# 7740        73.718290       18.592497                      0.003007    1325
# 7741        73.681119       17.951461                      0.084696    1527
# 7742        73.718290       18.592497                      0.003007    1550
#
#       budget_level
# 0                3
# 1                3
# 2                3
# 3                3
# 4                2
# ...            ...
# 7738             1
# 7739             1
# 7740             1
# 7741             1
# 7742             1
#
# [7743 rows x 49 columns]

# %%
combined_data.to_csv("Final_Prepared_data2.0.csv")

# %%
import pandas as pd

# Assuming your DataFrame is named 'combined_data1' and the budget column is named 'budget'
# You can replace these names with your actual DataFrame and column names

# Define the number of levels
num_levels = 5

# Create a new column 'budget_level' and assign levels based on the range
combined_data1['budget_level'] = pd.qcut(combined_data1['budget'], q=num_levels, labels=[f'Level_{i+1}' for i in range(num_levels)])

# Display the range for each level
for level in range(1, num_levels + 1):
    level_data = combined_data1[combined_data1['budget_level'] == f'Level_{level}']['budget']
    min_range = level_data.min()
    max_range = level_data.max()
    print(f'Level_{level} range: {min_range} to {max_range}')

# Display the DataFrame with the new column
print(combined_data1)

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_csv('Final_Prepared_data2.0.csv')

# Remove duplicate entries
dataset_without_duplicates = dataset.drop_duplicates()

# Optionally, you can overwrite the original dataset with the one without duplicates
# dataset.drop_duplicates(inplace=True)

# Save the dataset without duplicates to a new CSV file
dataset_without_duplicates.to_csv('dataset_without_duplicates.csv', index=False)

# %%
dataset_without_duplicates
# Out:
#       Unnamed: 0.1  Unnamed: 0            Restaurant_Name Locality_Restaurant  \
# 0                0           0  AB's - Absolute Barbecues           Hinjawadi
# 1                1           1  AB's - Absolute Barbecues           Hinjawadi
# 2                2           2  AB's - Absolute Barbecues           Hinjawadi
# 3                3           3  AB's - Absolute Barbecues           Hinjawadi
# 4                4           4  AB's - Absolute Barbecues           Hinjawadi
# ...            ...         ...                        ...                 ...
# 7738          7738        7738               Sambar House         Mulshi Road
# 7739          7739        7739             The Hungry Hog              Lavale
# 7740          7740        7740             The Hungry Hog              Lavale
# 7741          7741        7741     Rudra Restaurant & Bar         Mulshi Road
# 7742          7742        7742     Rudra Restaurant & Bar         Mulshi Road
#
#       Ratings_out_of_5_Restaurant  Price_Restaurant  Price Level__Restaurant  \
# 0                             4.9               700                        2
# 1                             4.9               700                        2
# 2                             4.9               700                        2
# 3                             4.9               700                        2
# 4                             4.9               700                        2
# ...                           ...               ...                      ...
# 7738                          0.0                75                        1
# 7739                          0.0               125                        1
# 7740                          0.0               125                        1
# 7741                          3.1               350                        1
# 7742                          3.1               350                        1
#
#       Latitude_x__Restaurant  Longitude_x__Restaurant  Nearest_Place_Index_0  \
# 0                  18.592753                73.738215                     44
# 1                  18.592753                73.738215                     44
# 2                  18.592753                73.738215                     44
# 3                  18.592753                73.738215                     44
# 4                  18.592753                73.738215                     44
# ...                      ...                      ...                    ...
# 7738               18.611846                73.717142                     38
# 7739               18.523023                73.722401                     38
# 7740               18.523023                73.722401                     38
# 7741               18.611846                73.717142                     38
# 7742               18.611846                73.717142                     38
#
#       ...                               Hotel_name  \
# 0     ...                  Executive Tamanna Hotel
# 1     ...   Ashiyana Hospitality Service Apartment
# 2     ...                    Siesta Hinjewadi Lxia
# 3     ...  Riverdale Hospitality Service Apartment
# 4     ...                       Hotel Elite Galaxy
# ...   ...                                      ...
# 7738  ...   Innovative Service Apartment Hinjewadi
# 7739  ...                            Gourish Hotel
# 7740  ...   Innovative Service Apartment Hinjewadi
# 7741  ...                            Gourish Hotel
# 7742  ...   Innovative Service Apartment Hinjewadi
#
#                        area_Hotel  hotel_star_rating_Hotel  \
# 0           Hinjewadi,Aundh,Wakad                        2
# 1                       Hinjewadi                        1
# 2      Hinjewadi,Wakad Naka,Wakad                        3
# 3                       Hinjewadi                        1
# 4     Rajiv Gandhi Infotech Park,                        2
# ...                           ...                      ...
# 7738                    Hinjewadi                        1
# 7739           Shivajinagar, pune                        1
# 7740                    Hinjewadi                        1
# 7741           Shivajinagar, pune                        1
# 7742                    Hinjewadi                        1
#
#       mmt_review_score_Hotel  Price_Hotel Longitude_Hotel  Latitude_Hotel  \
# 0                        3.7         1900       73.734974       18.585750
# 1                        3.4         2447       73.740133       18.578061
# 2                        4.5         1893       73.745629       18.591736
# 3                        2.8         2140       73.736188       18.580314
# 4                        4.0         1413       73.732535       18.599672
# ...                      ...          ...             ...             ...
# 7738                     5.0         1200       73.718290       18.592497
# 7739                     4.1         1177       73.681119       17.951461
# 7740                     5.0         1200       73.718290       18.592497
# 7741                     4.1         1177       73.681119       17.951461
# 7742                     5.0         1200       73.718290       18.592497
#
#       Distance_to_Place_form_Hotel  budget  budget_level
# 0                         0.000683    2600             3
# 1                         0.004711    3147             3
# 2                         0.010089    2593             3
# 3                         0.001087    2840             3
# 4                         0.003142    2113             2
# ...                            ...     ...           ...
# 7738                      0.003007    1275             1
# 7739                      0.084696    1302             1
# 7740                      0.003007    1325             1
# 7741                      0.084696    1527             1
# 7742                      0.003007    1550             1
#
# [7743 rows x 50 columns]

# %%
import pandas as pd
from sklearn.metrics.pairwise import haversine_distances, cosine_similarity
from math import radians

# Load the combined dataset
combined_data = pd.read_csv('dataset_without_duplicates.csv')

# Remove duplicate entries
combined_data.drop_duplicates(inplace=True)

# Example user input
user_budget_level = 1  # Example user budget level criterion
user_hotel_rating = 4  # Example user rating criterion
user_hotel_star_rating = 4  # Example user hotel star rating criterion
user_restaurant_rating = 2  # Example user restaurant rating criterion

# Filter based on user criteria, including the new budget level
filtered_data = combined_data[
    (combined_data['budget_level'] == user_budget_level) &
    (combined_data['mmt_review_score_Hotel'] >= user_hotel_rating) &
    (combined_data['hotel_star_rating_Hotel'] >= user_hotel_star_rating) &
    (combined_data['Ratings_out_of_5_Restaurant'] >= user_restaurant_rating)
]

# Check if the filtered dataset is empty
if filtered_data.empty:
    print("No suitable recommendations found based on the provided criteria.")
else:
    # Select the first restaurant based on budget level
    selected_restaurant = filtered_data.iloc[0]

    # Calculate distance to restaurant
    def calculate_distance(lat1, lon1, lat2, lon2):
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
        dist = haversine_distances([[lat1, lon1], [lat2, lon2]]) * 6371000  # Earth radius in meters
        return dist[1, 0]

    # Apply the distance calculation to hotels
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_Hotel'],
            row['Longitude_Hotel']
        ),
        axis=1
    )

    # Rank hotels based on distance and additional criteria
    ranked_hotels = filtered_data[filtered_data['Hotel_name'].notnull()].sort_values(
        by=['distance_to_restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']
    )

    # Select the nearest hotel if there are any
    if not ranked_hotels.empty:
        nearest_hotel = ranked_hotels.iloc[0]
    else:
        nearest_hotel = None

    # Apply the distance calculation to places
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_place_0_x'],
            row['Longitude_place_0_x']
        ),
        axis=1
    )

    # Rank places based on distance
    ranked_places = filtered_data[filtered_data['Name_Place'].notnull()].sort_values(by='distance_to_restaurant')

    # Select the nearest place if there are any
    if not ranked_places.empty:
        nearest_place = ranked_places.iloc[0]
    else:
        nearest_place = None

    # Content-Based Filtering - Item Similarity
    item_features = filtered_data[['Ratings_out_of_5_Restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']]
    selected_item_features = selected_restaurant[['Ratings_out_of_5_Restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']]

    # Calculate cosine similarity between items
    item_similarity = cosine_similarity([selected_item_features], item_features)

    # Get top 4 items based on similarity
    top_items = filtered_data.iloc[item_similarity.argsort()[0][::-1][:4]]

    # Display the recommendations
    print("Recommendations:")
    print("-----------------")
    print(f"Recommended Restaurant: {selected_restaurant['Restaurant_Name']}")

    if nearest_hotel is not None:
        print(f"Nearest Hotel: {nearest_hotel['Hotel_name']}")
    else:
        print("No hotels found meeting the criteria.")

    if nearest_place is not None:
        print(f"Nearest Place: {nearest_place['Name_Place']}")
    else:
        print("No places found meeting the criteria.")

    print("\nAdditional Information:")
    print("-----------------------")

    if nearest_hotel is not None:
        print(f"Distance to Nearest Hotel: {nearest_hotel['distance_to_restaurant']:.2f} meters")
        print(f"Hotel Rating: {nearest_hotel['mmt_review_score_Hotel']}")
        print(f"Hotel Star Rating: {nearest_hotel['hotel_star_rating_Hotel']}")
    else:
        print("No hotels found meeting the criteria.")

    print(f"Restaurant Rating: {selected_restaurant['Ratings_out_of_5_Restaurant']}")

    print("\nContent-Based Filtering - Top 4 Items:")
    print(top_items[['Restaurant_Name', 'Hotel_name', 'Name_Place']])
# Out:
# Recommendations:
# -----------------
# Recommended Restaurant: Baba Ramdev Dhaba
# Nearest Hotel: Hotel Ambience Executive
# Nearest Place: Mahasadhu Shree Moraya Gosavi Maharaj Sanjivan Samadhi Mandir
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 6656.98 meters
# Hotel Rating: 4.2
# Hotel Star Rating: 4
# Restaurant Rating: 4.2
#
# Content-Based Filtering - Top 4 Items:
#         Restaurant_Name                Hotel_name  \
# 6910  Baba Ramdev Dhaba  Hotel Ambience Executive
# 6934    The Kream Story  Hotel Ambience Executive
# 6918            Camios!  Hotel Ambience Executive
# 6916        Baker's Hut  Hotel Ambience Executive
#
#                                              Name_Place
# 6910  Mahasadhu Shree Moraya Gosavi Maharaj Sanjivan...
# 6934  Mahasadhu Shree Moraya Gosavi Maharaj Sanjivan...
# 6918  Mahasadhu Shree Moraya Gosavi Maharaj Sanjivan...
# 6916  Mahasadhu Shree Moraya Gosavi Maharaj Sanjivan...
# C:\Users\Athar\AppData\Local\Temp\ipykernel_11584\2022059934.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# C:\Users\Athar\AppData\Local\Temp\ipykernel_11584\2022059934.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(

# %%
import pandas as pd
from sklearn.metrics.pairwise import haversine_distances, cosine_similarity
from math import radians

# Load the combined dataset
combined_data = pd.read_csv('dataset_without_duplicates.csv')

# Remove duplicate entries
combined_data.drop_duplicates(inplace=True)

def calculate_distance(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dist = haversine_distances([[lat1, lon1], [lat2, lon2]]) * 6371000  # Earth radius in meters
    return dist[1, 0]

def get_recommendations(filtered_data, selected_restaurant):
    # Apply the distance calculation to hotels
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_Hotel'],
            row['Longitude_Hotel']
        ),
        axis=1
    )

    # Rank hotels based on distance and additional criteria
    ranked_hotels = filtered_data[filtered_data['Hotel_name'].notnull()].sort_values(
        by=['distance_to_restaurant', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel']
    )

    # Select the nearest hotel if there are any
    nearest_hotel = ranked_hotels.iloc[0] if not ranked_hotels.empty else None

    # Apply the distance calculation to places
    filtered_data['distance_to_restaurant'] = filtered_data.apply(
        lambda row: calculate_distance(
            selected_restaurant['Latitude_x__Restaurant'],
            selected_restaurant['Longitude_x__Restaurant'],
            row['Latitude_place_0_x'],
            row['Longitude_place_0_x']
        ),
        axis=1
    )

    # Rank places based on distance
    ranked_places = filtered_data[filtered_data['Name_Place'].notnull()].sort_values(by='distance_to_restaurant')

    # Select the nearest place if there are any
    nearest_place = ranked_places.iloc[0] if not ranked_places.empty else None

    # Collaborative Filtering - Content Similarity
    hotel_profiles = filtered_data[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]
    place_profiles = filtered_data[['Rating_Place', 'Ratings_out_of_5_Restaurant', 'budget_level']]

    selected_hotel_profile = selected_restaurant[['mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'budget_level']]

    hotel_similarity = cosine_similarity([selected_hotel_profile], hotel_profiles)
    place_similarity = cosine_similarity([selected_hotel_profile], place_profiles)

    # Get top 4 hotels and places based on similarity
    top_hotels = ranked_hotels.iloc[hotel_similarity.argsort()[0][::-1][:4]]
    top_places = ranked_places.iloc[place_similarity.argsort()[0][::-1][:4]]

    return nearest_hotel, nearest_place, top_hotels, top_places

# Example user input
user_budget_level = 1
user_hotel_rating = 1
user_hotel_star_rating = 1
user_restaurant_rating = 1
num_days = 3  # Example number of days

# Filter based on user criteria, including the new budget level
filtered_data = combined_data[
    (combined_data['budget_level'] == user_budget_level) &
    (combined_data['mmt_review_score_Hotel'] >= user_hotel_rating) &
    (combined_data['hotel_star_rating_Hotel'] == user_hotel_star_rating) &
    (combined_data['Ratings_out_of_5_Restaurant'] >= user_restaurant_rating)
]

# Check if the filtered dataset is empty
if filtered_data.empty:
    print("No suitable recommendations found based on the provided criteria.")
else:
    # Loop through the specified number of days to provide recommendations
    for day in range(1, num_days + 1):
        print(f"\nRecommendations for Day {day}:")
        print("-----------------------------")

        # Select the restaurant for the day (you might have a different logic to select it)
        selected_restaurant = filtered_data.sample(n=1).iloc[0]

        # Get recommendations for the selected restaurant
        nearest_hotel, nearest_place, top_hotels, top_places = get_recommendations(filtered_data, selected_restaurant)

        # Display the recommendations
        print(f"Recommended Restaurant: {selected_restaurant['Restaurant_Name']}")
        if nearest_hotel is not None:
            print(f"Nearest Hotel: {nearest_hotel['Hotel_name']}")
        else:
            print("No hotels found meeting the criteria.")

        if nearest_place is not None:
            print(f"Nearest Place: {nearest_place['Name_Place']}")
        else:
            print("No places found meeting the criteria.")

        print("\nAdditional Information:")
        print("-----------------------")
        if nearest_hotel is not None:
            print(f"Distance to Nearest Hotel: {nearest_hotel['distance_to_restaurant']:.2f} meters")
            print(f"Hotel Rating: {nearest_hotel['mmt_review_score_Hotel']}")
            print(f"Hotel Star Rating: {nearest_hotel['hotel_star_rating_Hotel']}")
        else:
            print("No hotels found meeting the criteria.")

        print(f"Restaurant Rating: {selected_restaurant['Ratings_out_of_5_Restaurant']}")

        print("\nCollaborative Filtering - Top 4 Hotels:")
        print(top_hotels[['Hotel_name', 'mmt_review_score_Hotel', 'hotel_star_rating_Hotel', 'distance_to_restaurant']])
        print("\nCollaborative Filtering - Top 4 Places:")
        print(top_places[['Name_Place', 'Ratings_out_of_5_Restaurant', 'distance_to_restaurant']])
# Out:
# Recommendations for Day 1:
# -----------------------------
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# Recommended Restaurant: Bedekar Tea Stall
# Nearest Hotel: Hotel Vijay Lodge
# Nearest Place: Shri Ahobila Mutt's Shri Balaji Mandir
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 1399.84 meters
# Hotel Rating: 3.7
# Hotel Star Rating: 1
# Restaurant Rating: 3.9
#
# Collaborative Filtering - Top 4 Hotels:
#                                Hotel_name  mmt_review_score_Hotel  \
# 3265                    Hotel Yashraj Inn                     3.5
# 3165                    Hotel Yashraj Inn                     3.5
# 5311  Amigo Service Apartment - Chinchwad                     3.8
# 5309  Amigo Service Apartment - Chinchwad                     3.8
#
#       hotel_star_rating_Hotel  distance_to_restaurant
# 3265                        1            15225.231752
# 3165                        1            15225.231752
# 5311                        1            15514.418207
# 5309                        1            15514.418207
#
# Collaborative Filtering - Top 4 Places:
#                                 Name_Place  Ratings_out_of_5_Restaurant  \
# 4084  Phoenix Mall of the Millennium Wakad                          3.8
# 4438  Phoenix Mall of the Millennium Wakad                          3.3
# 3370             Raja Dinkar Kelkar Museum                          4.2
# 2306          Rajiv Gandhi Zoological Park                          3.3
#
#       distance_to_restaurant
# 4084            14623.186637
# 4438            14623.186637
# 3370            18511.179066
# 2306            11581.367692
#
# Recommendations for Day 2:
# -----------------------------
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# Recommended Restaurant: Italy Via Punjab
# Nearest Hotel: Hotel Yashraj Inn
# Nearest Place: Rajiv Gandhi Zoological Park
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 934341.14 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 4.1
#
# Collaborative Filtering - Top 4 Hotels:
#                         Hotel_name  mmt_review_score_Hotel  \
# 1226  Hotel Krishna Palace Wagholi                     3.3
# 3255             Hotel Yashraj Inn                     3.5
# 3226  Hotel Krishna Palace Wagholi                     3.3
# 3246  Hotel Krishna Palace Wagholi                     3.3
#
#       hotel_star_rating_Hotel  distance_to_restaurant
# 1226                        1           934982.449969
# 3255                        1           934341.137636
# 3226                        1           934982.449969
# 3246                        1           934982.449969
#
# Collaborative Filtering - Top 4 Places:
#                                              Name_Place  \
# 4084               Phoenix Mall of the Millennium Wakad
# 4438               Phoenix Mall of the Millennium Wakad
# 3370                          Raja Dinkar Kelkar Museum
# 6258  Gadima Bungalow (पंचवटी | Panchawati) / Ga Di ...
#
#       Ratings_out_of_5_Restaurant  distance_to_restaurant
# 4084                          3.8           956832.560987
# 4438                          3.3           956832.560987
# 3370                          4.2           963577.543838
# 6258                          4.0           948024.462863
#
# Recommendations for Day 3:
# -----------------------------
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(
# Recommended Restaurant: Rashid Khan Caterers
# Nearest Hotel: Hotel Yashraj Inn
# Nearest Place: Rajiv Gandhi Zoological Park
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 228272.99 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 3.6
#
# Collaborative Filtering - Top 4 Hotels:
#                         Hotel_name  mmt_review_score_Hotel  \
# 1226  Hotel Krishna Palace Wagholi                     3.3
# 3255             Hotel Yashraj Inn                     3.5
# 3226  Hotel Krishna Palace Wagholi                     3.3
# 3246  Hotel Krishna Palace Wagholi                     3.3
#
#       hotel_star_rating_Hotel  distance_to_restaurant
# 1226                        1           228698.984485
# 3255                        1           228272.986661
# 3226                        1           228698.984485
# 3246                        1           228698.984485
#
# Collaborative Filtering - Top 4 Places:
#                                 Name_Place  Ratings_out_of_5_Restaurant  \
# 4084  Phoenix Mall of the Millennium Wakad                          3.8
# 4438  Phoenix Mall of the Millennium Wakad                          3.3
# 3370             Raja Dinkar Kelkar Museum                          4.2
# 7698              pataleshwar cave temples                          4.1
#
#       distance_to_restaurant
# 4084           250458.771104
# 4438           250458.771104
# 3370           255482.613399
# 7698           237796.754420
# C:\Users\Athar\AppData\Local\Temp\ipykernel_23604\4260301040.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['distance_to_restaurant'] = filtered_data.apply(

# %%
# Out:
# Recommendations for Day 1:
# -----------------------------
# Recommended Restaurant: Hotel Shahu
# Nearest Hotel: Hotel Vijay Lodge
# Nearest Place: Shri Ahobila Mutt's Shri Balaji Mandir
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 1399.84 meters
# Hotel Rating: 3.7
# Hotel Star Rating: 1
# Restaurant Rating: 3.2
#
# Collaborative Filtering - Top 4 Hotels:
#                        Hotel_name  mmt_review_score_Hotel  \
# 13              Hotel Vijay Lodge                     3.7
# 212  Hotel Krishna Palace Wagholi                     3.3
# 691  Hotel Krishna Palace Wagholi                     3.3
# 682  Hotel Krishna Palace Wagholi                     3.3
#
#      hotel_star_rating_Hotel  distance_to_restaurant
# 13                         1             1399.838022
# 212                        1            14561.645513
# 691                        1            14561.645513
# 682                        1            14561.645513
#
# Collaborative Filtering - Top 4 Places:
#                        Name_Place  Ratings_out_of_5_Restaurant  \
# 905                Darshan Museum                          4.0
# 174             Bliss Art Gallery                          4.0
# 790  Rajiv Gandhi Zoological Park                          3.9
# 634  Rajiv Gandhi Zoological Park                          3.8
#
#      distance_to_restaurant
# 905             3139.518584
# 174             5643.246924
# 790            11581.367692
# 634            11581.367692
#
# Recommendations for Day 2:
# -----------------------------
# Recommended Restaurant: Cafe Bistro
# Nearest Hotel: Gourish Hotel
# Nearest Place: Rajiv Gandhi Zoological Park
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 50046.98 meters
# Hotel Rating: 4.1
# Hotel Star Rating: 1
# Restaurant Rating: 3.9
#
# Collaborative Filtering - Top 4 Hotels:
#                               Hotel_name  mmt_review_score_Hotel  \
# 333                    Hotel Yashraj Inn                     3.5
# 340                    Hotel Yashraj Inn                     3.5
# 37   Amigo Service Apartment - Chinchwad                     3.8
# 410                    Hotel Yashraj Inn                     3.5
#
#      hotel_star_rating_Hotel  distance_to_restaurant
# 333                        1            91475.416749
# 340                        1            91475.416749
# 37                         1           102216.905959
# 410                        1            91475.416749
#
# Collaborative Filtering - Top 4 Places:
#                        Name_Place  Ratings_out_of_5_Restaurant  \
# 890     Raja Dinkar Kelkar Museum                          4.5
# 72                  Kalakar Katha                          3.4
# 78   Rajiv Gandhi Zoological Park                          3.6
# 310  Rajiv Gandhi Zoological Park                          3.1
#
#      distance_to_restaurant
# 890           101277.355331
# 72             88191.819593
# 78             81519.045372
# 310            81519.045372
#
# Recommendations for Day 3:
# -----------------------------
# Recommended Restaurant: Granny Ammaas Cake
# Nearest Hotel: Hotel Yashraj Inn
# Nearest Place: Rajiv Gandhi Zoological Park
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 228272.99 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 3.8
#
# Collaborative Filtering - Top 4 Hotels:
#                        Hotel_name  mmt_review_score_Hotel  \
# 771             Hotel Green Plaza                     3.7
# 619  Hotel Krishna Palace Wagholi                     3.3
# 812           Hotel Santosh Lodge                     4.0
# 613  Hotel Krishna Palace Wagholi                     3.3
#
#      hotel_star_rating_Hotel  distance_to_restaurant
# 771                        1           233808.530064
# 619                        1           228698.984485
# 812                        1           245073.440349
# 613                        1           228698.984485
#
# Collaborative Filtering - Top 4 Places:
#                        Name_Place  Ratings_out_of_5_Restaurant  \
# 93       pataleshwar cave temples                          3.4
# 367     Raja Dinkar Kelkar Museum                          3.9
# 370     Raja Dinkar Kelkar Museum                          2.8
# 143  Rajiv Gandhi Zoological Park                          4.1
#
#      distance_to_restaurant
# 93            237796.754420
# 367           255482.613399
# 370           255482.613399
# 143           225586.412136

# %%
print(combined_data.head())  # Print the first few rows of the DataFrame
print(combined_data.shape)   # Print the shape of the DataFrame (number of rows and columns)
# Out:
#    user_id            Restaurant_Name Locality_Restaurant  \
# 0        0  AB's - Absolute Barbecues           Hinjawadi
# 1        1  AB's - Absolute Barbecues           Hinjawadi
# 2        2  AB's - Absolute Barbecues           Hinjawadi
# 3        3  AB's - Absolute Barbecues           Hinjawadi
# 4        4  AB's - Absolute Barbecues           Hinjawadi
#
#    Ratings_out_of_5_Restaurant  Price_Restaurant  Price Level__Restaurant  \
# 0                          4.9               700                        2
# 1                          4.9               700                        2
# 2                          4.9               700                        2
# 3                          4.9               700                        2
# 4                          4.9               700                        2
#
#    Latitude_x__Restaurant  Longitude_x__Restaurant  Nearest_Place_Index_0  \
# 0               18.592753                73.738215                     44
# 1               18.592753                73.738215                     44
# 2               18.592753                73.738215                     44
# 3               18.592753                73.738215                     44
# 4               18.592753                73.738215                     44
#
#    Distance_to_Place_0_from__Restaurant  ...  \
# 0                              0.002686  ...
# 1                              0.002686  ...
# 2                              0.002686  ...
# 3                              0.002686  ...
# 4                              0.002686  ...
#
#                                 Hotel_name                   area_Hotel  \
# 0                  Executive Tamanna Hotel        Hinjewadi,Aundh,Wakad
# 1   Ashiyana Hospitality Service Apartment                    Hinjewadi
# 2                    Siesta Hinjewadi Lxia   Hinjewadi,Wakad Naka,Wakad
# 3  Riverdale Hospitality Service Apartment                    Hinjewadi
# 4                       Hotel Elite Galaxy  Rajiv Gandhi Infotech Park,
#
#    hotel_star_rating_Hotel  mmt_review_score_Hotel Price_Hotel  \
# 0                        2                     3.7        1900
# 1                        1                     3.4        2447
# 2                        3                     4.5        1893
# 3                        1                     2.8        2140
# 4                        2                     4.0        1413
#
#    Longitude_Hotel  Latitude_Hotel  Distance_to_Place_form_Hotel  budget  \
# 0        73.734974       18.585750                      0.000683    2600
# 1        73.740133       18.578061                      0.004711    3147
# 2        73.745629       18.591736                      0.010089    2593
# 3        73.736188       18.580314                      0.001087    2840
# 4        73.732535       18.599672                      0.003142    2113
#
#    budget_level
# 0             3
# 1             3
# 2             3
# 3             3
# 4             2
#
# [5 rows x 49 columns]
# (7684, 49)

# %%
# Out:
# Recommendations for Day 1:
# -----------------------------
# Recommended Restaurant: Jaiwal's Cafe and Chinese
# Nearest Hotel: Galaxy Service Apartment
# Nearest Place: Phoenix Marketcity Pune
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 2521.38 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 3.7
#
# Collaborative Filtering - Top 4 Hotels:
#                    Hotel_name  mmt_review_score_Hotel  \
# 430         Hotel Yashraj Inn                     3.5
# 19   Ranjanas Hospitality LLP                     4.3
# 38   Ranjanas Hospitality LLP                     4.3
# 871         Hotel Yashraj Inn                     3.5
#
#      hotel_star_rating_Hotel  distance_to_restaurant
# 430                        1             5989.305288
# 19                         1            17523.876039
# 38                         1            17523.876039
# 871                        1             5989.305288
#
# Collaborative Filtering - Top 4 Places:
#                        Name_Place  Ratings_out_of_5_Restaurant  \
# 233  Rajiv Gandhi Zoological Park                          3.3
# 250  Rajiv Gandhi Zoological Park                          4.0
# 263  Rajiv Gandhi Zoological Park                          4.4
# 449     Raja Dinkar Kelkar Museum                          3.9
#
#      distance_to_restaurant
# 233            11312.182581
# 250            11312.182581
# 263            11312.182581
# 449            23644.012254
#
# Recommendations for Day 2:
# -----------------------------
# C:\Users\Athar\AppData\Local\Temp\ipykernel_14436\3613885484.py:134: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ground_truth_df = pd.concat([ground_truth_df, pd.DataFrame({
# Recommended Restaurant: Jalebi Junction
# Nearest Hotel: Hotel Yashraj Inn
# Nearest Place: Rajiv Gandhi Zoological Park
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 493118.60 meters
# Hotel Rating: 3.5
# Hotel Star Rating: 1
# Restaurant Rating: 3.4
#
# Collaborative Filtering - Top 4 Hotels:
#                               Hotel_name  mmt_review_score_Hotel  \
# 728                    Hotel Yashraj Inn                     3.5
# 326         Hotel Krishna Palace Wagholi                     3.3
# 61   Amigo Service Apartment - Chinchwad                     3.8
# 576                        Nikhil Garden                     4.2
#
#      hotel_star_rating_Hotel  distance_to_restaurant
# 728                        1           493118.600270
# 326                        1           493643.668411
# 61                         1           508605.949189
# 576                        1           505177.727427
#
# Collaborative Filtering - Top 4 Places:
#                                             Name_Place  \
# 866                            Phoenix Marketcity Pune
# 262                       Rajiv Gandhi Zoological Park
# 859                          Raja Dinkar Kelkar Museum
# 151  Gadima Bungalow (पंचवटी | Panchawati) / Ga Di ...
#
#      Ratings_out_of_5_Restaurant  distance_to_restaurant
# 866                          4.0           498732.281639
# 262                          3.2           492554.363610
# 859                          3.8           522087.040074
# 151                          3.9           504808.659612
#
# Recommendations for Day 3:
# -----------------------------
# Recommended Restaurant: द Vege टेबल
# Nearest Hotel: Hotel Vijay Lodge
# Nearest Place: Kalakar Katha
#
# Additional Information:
# -----------------------
# Distance to Nearest Hotel: 1080.78 meters
# Hotel Rating: 3.7
# Hotel Star Rating: 1
# Restaurant Rating: 4.1
#
# Collaborative Filtering - Top 4 Hotels:
#             Hotel_name  mmt_review_score_Hotel  hotel_star_rating_Hotel  \
# 149     Hotel Ravikant                     3.5                        1
# 493     Hotel Shiv Inn                     2.9                        1
# 112  Hotel Yashraj Inn                     3.5                        1
# 445     Hotel Shiv Inn                     2.9                        1
#
#      distance_to_restaurant
# 149             4790.514547
# 493            30654.887660
# 112            15721.745404
# 445            30654.887660
#
# Collaborative Filtering - Top 4 Places:
#                                             Name_Place  \
# 285               Phoenix Mall of the Millennium Wakad
# 446                                     Darshan Museum
# 189  Gadima Bungalow (पंचवटी | Panchawati) / Ga Di ...
# 859                                      Kalakar Katha
#
#      Ratings_out_of_5_Restaurant  distance_to_restaurant
# 285                          4.4            13637.512661
# 446                          3.2             3749.175191
# 189                          3.7             2593.886316
# 859                          4.4              212.448942
